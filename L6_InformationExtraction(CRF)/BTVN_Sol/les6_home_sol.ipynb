# %% [markdown]
# # Gán nhãn từ loại với mô hình Markov ẩn
# Notebook này hướng dẫn sử dụng mô hình Markov ẩn (HMM) để thực hiện gán nhãn dữ liệu. Chúng ta sẽ sử dụng Python để xây dựng một mô hình gán nhãn dữ liệu bằng HMM và thuật toán Veterbi

# %% [markdown]
# Đọc dữ liệu và tổ chức dữ liệu huấn luyện

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
import pprint, time
 
# Tiến hành đọc dữ liệu: đầu ra là danh sách các câu, mỗi một câu là một danh sách cặp các token và nhãn tương ứng.
file_path = '/content/drive/MyDrive/NLP/Đáp án cho bài tập về nhà/Lesson6/train.conll'
def load_data(file_path):
  ### 1. BEGIN CODE HERE ###
  f = open(file_path,'r',encoding='utf-8')
  data = []
  sentence = []
  for line in f:
    if line == '\n':
      data.append(sentence)
      sentence = []
    else:
      args = line.split()
      sentence.append((args[0],args[-1]))
  f.close()
  return data
  ### 1. END CODE HERE ###

data = load_data(file_path)

# %%
# Chia bộ dữ liệu thành 2 tập train, test với tỷ lệ 80:20
### 2. BEGIN CODE HERE ###
train_set,test_set =train_test_split(data,train_size=0.8,test_size=0.2,random_state = 101)
### 2. END CODE HERE ###

# %%
print(len(train_set))
print(len(test_set))
# Out:
# 6212
# 1553

# %%
# Tạo danh sách các cặp (word tagged) ở các tập train và test
### 3. BEGIN CODE HERE ###
train_tagged_words = [ tup for sent in train_set for tup in sent ]
test_tagged_words = [ tup for sent in test_set for tup in sent ]
### 3. BEGIN CODE HERE ###
print(len(train_tagged_words))
print(len(test_tagged_words))
# Out:
# 143656
# 36217

# %%
# Kiểm tra 5 cặp đầu tiên
train_tagged_words[:5]
# Out:
# [('Vai', 'O'), ('trò', 'O'), ('người', 'O'), ('đứng', 'O'), ('đầu', 'O')]

# %%
#use set datatype to check how many unique tags are present in training data
tags = {tag for word,tag in train_tagged_words}
print(len(tags))
print(tags)
 
# check total words in vocabulary
vocab = {word for word,tag in train_tagged_words}
# Out:
# 9
# {'I-PERSON', 'B-LOCATION', 'O', 'I-LOCATION', 'B-DATETIME', 'I-DATETIME', 'B-ORGANIZATION', 'I-ORGANIZATION', 'B-PERSON'}

# %%
train_tagged_words
# Out:
# [('Vai', 'O'),
#  ('trò', 'O'),
#  ('người', 'O'),
#  ('đứng', 'O'),
#  ('đầu', 'O'),
#  ('là', 'O'),
#  ('vậy,', 'O'),
#  ('còn', 'O'),
#  ('khi', 'O'),
#  ('triển', 'O'),
#  ('khai', 'O'),
#  ('xuống', 'O'),
#  ('các', 'O'),
#  ('cấp', 'O'),
#  ('dưới,', 'O'),
#  ('nếu', 'O'),
#  ('học', 'O'),
#  ('cho', 'O'),
#  ('có,', 'O'),
#  ('không', 'O'),
#  ('thảo', 'O'),
#  ('luận,', 'O'),
#  ('không', 'O'),
#  ('kiểm', 'O'),
#  ('tra', 'O'),
#  ('thì', 'O'),
#  ('vận', 'O'),
#  ('dụng', 'O'),
#  ('vào', 'O'),
#  ('thực', 'O'),
#  ('tế', 'O'),
#  ('sẽ', 'O'),
#  ('rất', 'O'),
#  ('khó..', 'O'),
#  ('Tuy', 'O'),
#  ('nhiên,', 'O'),
#  ('sẽ', 'O'),
#  ('có', 'O'),
#  ('những', 'O'),
#  ('điều', 'O'),
#  ('mà', 'O'),
#  ('không', 'O'),
#  ('thể', 'O'),
#  ('làm', 'O'),
#  ('thỏa', 'O'),
#  ('mãn', 'O'),
#  ('được', 'O'),
#  ('cho', 'O'),
#  ('cả', 'O'),
#  ('hai', 'O'),
#  ('bên..', 'O'),
#  ('Các', 'O'),
#  ('Bộ,', 'O'),
#  ('ngành,', 'O'),
#  ('địa', 'O'),
#  ('phương', 'O'),
#  ('tăng', 'O'),
#  ('cường', 'O'),
#  ('tổ', 'O'),
#  ('chức', 'O'),
#  ('đối', 'O'),
#  ('thoại,', 'O'),
#  ('tiếp', 'O'),
#  ('công', 'O'),
#  ('dân,', 'O'),
#  ('kịp', 'O'),
#  ('thời', 'O'),
#  ('tháo', 'O'),
#  ('gỡ', 'O'),
#  ('khó', 'O'),
#  ('khăn,', 'O'),
#  ('vướng', 'O'),
#  ('mắc', 'O'),
#  ('và', 'O'),
#  ('xử', 'O'),
#  ('lý', 'O'),
#  ('kiến', 'O'),
#  ('nghị', 'O'),
#  ('của', 'O'),
#  ('người', 'O'),
#  ('dân,', 'O'),
#  ('doanh', 'O'),
#  ('nghiệp..', 'O'),
#  ('Tuy', 'O'),
#  ('nhiên,', 'O'),
#  ('bất', 'O'),
#  ('chấp', 'O'),
#  ('những', 'O'),
#  ('lợi', 'O'),
#  ('ích', 'O'),
#  ('của', 'O'),
#  ('việc', 'O'),
#  ('mua', 'O'),
#  ('thời', 'O'),
#  ('gian,', 'O'),
#  ('cuộc', 'O'),
#  ('nghiên', 'O'),
#  ('cứu', 'O'),
#  ('cho', 'O'),
#  ('thấy', 'O'),
#  ('nhiều', 'O'),
#  ('người', 'O'),
#  ('trong', 'O'),
#  ('chúng', 'O'),
#  ('ta', 'O'),
#  ('không', 'O'),
#  ('chọn', 'O'),
#  ('tiêu', 'O'),
#  ('xài', 'O'),
#  ('theo', 'O'),
#  ('kiểu', 'O'),
#  ('này,', 'O'),
#  ('ngay', 'O'),
#  ('cả', 'O'),
#  ('khi', 'O'),
#  ('chúng', 'O'),
#  ('ta', 'O'),
#  ('có', 'O'),
#  ('thể', 'O'),
#  ('trang', 'O'),
#  ('trải', 'O'),
#  ('điều', 'O'),
#  ('đó..', 'O'),
#  ('Nhiều', 'O'),
#  ('trẻ', 'O'),
#  ('mắc', 'O'),
#  ('các', 'O'),
#  ('bệnh', 'O'),
#  ('đường', 'O'),
#  ('hô', 'O'),
#  ('hấp', 'O'),
#  ('với', 'O'),
#  ('biểu', 'O'),
#  ('hiện', 'O'),
#  ('hắt', 'O'),
#  ('hơi,', 'O'),
#  ('sổ', 'O'),
#  ('mũi,', 'O'),
#  ('viêm', 'O'),
#  ('phế', 'O'),
#  ('quản', 'O'),
#  ('Trẻ', 'O'),
#  ('bị', 'O'),
#  ('hen', 'O'),
#  ('cũng', 'O'),
#  ('có', 'O'),
#  ('dấu', 'O'),
#  ('hiệu', 'O'),
#  ('tăng', 'O'),
#  ('lên..', 'O'),
#  ('Theo', 'O'),
#  ('tàu', 'O'),
#  ('tốc', 'O'),
#  ('hành', 'O'),
#  (',', 'O'),
#  ('đó', 'O'),
#  ('không', 'O'),
#  ('phải', 'O'),
#  ('mục', 'O'),
#  ('tiêu', 'O'),
#  ('của', 'O'),
#  ('anh', 'O'),
#  ('nhưng', 'O'),
#  ('nếu', 'O'),
#  ('có', 'O'),
#  ('cơ', 'O'),
#  ('hội,', 'O'),
#  ('anh', 'O'),
#  ('sẽ', 'O'),
#  ('nắm', 'O'),
#  ('bắt..', 'O'),
#  ('Thi', 'O'),
#  ('thể', 'O'),
#  ('ba', 'O'),
#  ('mẹ', 'O'),
#  ('con', 'O'),
#  ('nạn', 'O'),
#  ('nhân', 'O'),
#  ('được', 'O'),
#  ('đưa', 'O'),
#  ('về', 'O'),
#  ('nhà', 'O'),
#  ('xác..', 'O'),
#  ('Thậm', 'O'),
#  ('chí,', 'O'),
#  ('với', 'O'),
#  ('ước', 'O'),
#  ('mơ', 'O'),
#  ('có', 'O'),
#  ('căn', 'O'),
#  ('nhà', 'O'),
#  ('để', 'O'),
#  ('ổn', 'O'),
#  ('định', 'O'),
#  ('thì', 'O'),
#  ('có', 'O'),
#  ('công', 'O'),
#  ('nhân', 'O'),
#  ('gom', 'O'),
#  ('tiền', 'O'),
#  ('đi', 'O'),
#  ('mua', 'O'),
#  ('nhà', 'O'),
#  ('phân', 'O'),
#  ('lô,', 'O'),
#  ('bán', 'O'),
#  ('nền', 'O'),
#  ('giá', 'O'),
#  ('rẻ', 'O'),
#  ('nên', 'O'),
#  ('đầy', 'O'),
#  ('rủi', 'O'),
#  ('ro...', 'O'),
#  ('Các', 'O'),
#  ('công', 'O'),
#  ('nhân', 'O'),
#  ('kiến', 'O'),
#  ('nghị', 'O'),
#  ('với', 'O'),
#  ('Thủ', 'O'),
#  ('tướng..', 'O'),
#  ('Một', 'O'),
#  ('số', 'O'),
#  ('quần', 'O'),
#  ('chúng', 'O'),
#  ('báo', 'O'),
#  ('tin', 'O'),
#  ('có', 'O'),
#  ('thanh', 'O'),
#  ('niên', 'O'),
#  ('tên', 'O'),
#  ('Tăng', 'B-PERSON'),
#  ('ở', 'O'),
#  ('gần', 'O'),
#  ('nhà', 'O'),
#  ('nạn', 'O'),
#  ('nhân', 'O'),
#  ('vừa', 'O'),
#  ('vội', 'O'),
#  ('rời', 'O'),
#  ('địa', 'O'),
#  ('phương..', 'O'),
#  ('Giá', 'O'),
#  ('lùn', 'O'),
#  ('từ', 'O'),
#  ('khoảng', 'O'),
#  ('3', 'O'),
#  ('ngày', 'O'),
#  ('thu', 'O'),
#  ('hoạch,', 'O'),
#  ('còn', 'O'),
#  ('giá', 'O'),
#  ('dài', 'O'),
#  ('từ', 'O'),
#  ('4', 'O'),
#  ('5', 'O'),
#  ('ngày', 'O'),
#  ('trở', 'O'),
#  ('lên', 'O'),
#  (',', 'O'),
#  ('ông', 'O'),
#  ('Sang', 'B-PERSON'),
#  ('cho', 'O'),
#  ('biết..', 'O'),
#  ('Ảnh:', 'O'),
#  ('CTV', 'B-ORGANIZATION'),
#  ('Sau', 'O'),
#  ('khi', 'O'),
#  ('lập', 'O'),
#  ('biên', 'O'),
#  ('bản,', 'O'),
#  ('toàn', 'O'),
#  ('bộ', 'O'),
#  ('lượng', 'O'),
#  ('hàng', 'O'),
#  ('hóa', 'O'),
#  ('trên', 'O'),
#  ('đã', 'O'),
#  ('bị', 'O'),
#  ('cơ', 'O'),
#  ('quan', 'O'),
#  ('chức', 'O'),
#  ('năng', 'O'),
#  ('niêm', 'O'),
#  ('phong', 'O'),
#  ('và', 'O'),
#  ('tịch', 'O'),
#  ('thu..', 'O'),
#  ('Trong', 'O'),
#  ('lúc', 'O'),
#  ('tìm', 'O'),
#  ('kiếm', 'O'),
#  ('phương', 'O'),
#  ('pháp', 'O'),
#  ('mới', 'O'),
#  ('điều', 'O'),
#  ('trị', 'O'),
#  ('bệnh', 'O'),
#  ('tim,', 'O'),
#  ('các', 'O'),
#  ('nhà', 'O'),
#  ('nghiên', 'O'),
#  ('cứu', 'O'),
#  ('đã', 'O'),
#  ('nuôi', 'O'),
#  ('lớn', 'O'),
#  ('một', 'O'),
#  ('quả', 'O'),
#  ('tim', 'O'),
#  ('chuột', 'O'),
#  ('trong', 'O'),
#  ('phòng', 'O'),
#  ('thí', 'O'),
#  ('nghiệm,', 'O'),
#  ('và', 'O'),
#  ('bắt', 'O'),
#  ('đầu', 'O'),
#  ('cho', 'O'),
#  ('nó', 'O'),
#  ('nhịp', 'O'),
#  ('đập', 'O'),
#  ('y', 'O'),
#  ('như', 'O'),
#  ('quả', 'O'),
#  ('tim', 'O'),
#  ('người..', 'O'),
#  ('Các', 'O'),
#  ('giải', 'O'),
#  ('đôi:', 'O'),
#  ('Minh', 'B-PERSON'),
#  ('Quân', 'I-PERSON'),
#  ('-', 'O'),
#  ('Quang', 'B-PERSON'),
#  ('Huy', 'I-PERSON'),
#  ('đoạt', 'O'),
#  ('chức', 'O'),
#  ('vô', 'O'),
#  ('địch', 'O'),
#  ('nam,', 'O'),
#  ('Đài', 'B-PERSON'),
#  ('Trang', 'I-PERSON'),
#  ('-', 'O'),
#  ('Thanh', 'B-PERSON'),
#  ('Bình', 'I-PERSON'),
#  ('(Đà', 'B-LOCATION'),
#  ('Nẵng)', 'I-LOCATION'),
#  ('vô', 'O'),
#  ('địch', 'O'),
#  ('đôi', 'O'),
#  ('nữ', 'O'),
#  ('thắng', 'O'),
#  ('Tâm', 'B-PERSON'),
#  ('Hảo', 'I-PERSON'),
#  ('-', 'O'),
#  ('Lam', 'B-PERSON'),
#  ('Anh..', 'I-PERSON'),
#  ('Tay', 'O'),
#  ('vợt', 'O'),
#  ('người', 'O'),
#  ('Nhật', 'B-LOCATION'),
#  ('Bản', 'I-LOCATION'),
#  ('đã', 'O'),
#  ('thắng', 'O'),
#  ('Dinar', 'B-PERSON'),
#  ('Ayustine', 'I-PERSON'),
#  ('(Indonesia)', 'B-LOCATION'),
#  ('2-0', 'O'),
#  ('ở', 'O'),
#  ('trận', 'O'),
#  ('bán', 'O'),
#  ('kết', 'O'),
#  ('còn', 'O'),
#  ('lại..', 'O'),
#  ('Họ', 'O'),
#  ('cần', 'O'),
#  ('một', 'O'),
#  ('chiến', 'O'),
#  ('lược', 'O'),
#  ('gia', 'O'),
#  ('đủ', 'O'),
#  ('khả', 'O'),
#  ('năng', 'O'),
#  ('để', 'O'),
#  ('xây', 'O'),
#  ('dựng', 'O'),
#  ('nên', 'O'),
#  ('một', 'O'),
#  ('The', 'O'),
#  ('Kop', 'O'),
#  ('có', 'O'),
#  ('bản', 'O'),
#  ('sắc', 'O'),
#  ('riêng', 'O'),
#  ('như', 'O'),
#  ('ngày', 'O'),
#  ('nào..', 'O'),
#  ('Nữ', 'O'),
#  ('binh', 'O'),
#  ('sĩ', 'O'),
#  ('trong', 'O'),
#  ('quân', 'O'),
#  ('phục', 'O'),
#  ('trắng', 'O'),
#  ('luyện', 'O'),
#  ('tập', 'O'),
#  ('trên', 'O'),
#  ('quảng', 'O'),
#  ('trường', 'O'),
#  ('Cung', 'O'),
#  ('điện..', 'O'),
#  ('Hiện', 'O'),
#  ('tại,', 'O'),
#  ('Gangwon', 'B-ORGANIZATION'),
#  ('FC', 'I-ORGANIZATION'),
#  ('thường', 'O'),
#  ('xuyên', 'O'),
#  ('sử', 'O'),
#  ('dụng', 'O'),
#  ('đội', 'O'),
#  ('hình', 'O'),
#  ('mạnh', 'O'),
#  ('nhất', 'O'),
#  ('trong', 'O'),
#  ('những', 'O'),
#  ('trận', 'O'),
#  ('đấu', 'O'),
#  ('để', 'O'),
#  ('hoàn', 'O'),
#  ('thành', 'O'),
#  ('mục', 'O'),
#  ('tiêu', 'O'),
#  ('lọt', 'O'),
#  ('Top', 'O'),
#  ('3', 'O'),
#  ('tại', 'O'),
#  ('3', 'O'),
#  ('K-League', 'B-ORGANIZATION'),
#  ('Classic', 'O'),
#  ('2017..', 'O'),
#  ('Mọi', 'O'),
#  ('chứng', 'O'),
#  ('cứ', 'O'),
#  ('đều', 'O'),
#  ('nhắm', 'O'),
#  ('đến', 'O'),
#  ('một', 'O'),
#  ('sát', 'O'),
#  ('thủ,', 'O'),
#  ('còn', 'O'),
#  ('được', 'O'),
#  ('biết', 'O'),
#  ('đến', 'O'),
#  ('với', 'O'),
#  ('danh', 'O'),
#  ('nghĩa', 'O'),
#  ('là', 'O'),
#  ('một', 'O'),
#  ('cựu', 'O'),
#  ('quân', 'O'),
#  ('nhân,', 'O'),
#  ('một', 'O'),
#  ('tay', 'O'),
#  ('bắn', 'O'),
#  ('tỉa', 'O'),
#  ('thiện', 'O'),
#  ('nghệ..', 'O'),
#  ('Với', 'O'),
#  ('tổng', 'O'),
#  ('tài', 'O'),
#  ('sản', 'O'),
#  ('2,1', 'O'),
#  ('tỷ', 'O'),
#  ('USD,', 'O'),
#  ('Goh', 'B-PERSON'),
#  ('Cheng', 'I-PERSON'),
#  ('Liang', 'I-PERSON'),
#  ('đã', 'O'),
#  ('trở', 'O'),
#  ('thành', 'O'),
#  ('tỷ', 'O'),
#  ('phú', 'O'),
#  ('mới', 'O'),
#  ('nhất', 'O'),
#  ('ở', 'O'),
#  ('Singapore..', 'B-LOCATION'),
#  ('Xem', 'O'),
#  ('video', 'O'),
#  ('tổng', 'O'),
#  ('hợp', 'O'),
#  ('những', 'O'),
#  ('cột', 'O'),
#  ('mốc', 'O'),
#  ('ấn', 'O'),
#  ('tượng', 'O'),
#  ('của', 'O'),
#  ('Neymar', 'B-PERSON'),
#  ('ở', 'O'),
#  ('Barca', 'B-ORGANIZATION'),
#  ('(Nguồn', 'O'),
#  ('VTV)', 'O'),
#  (':', 'O'),
#  ('Neymar', 'B-PERSON'),
#  ('tẩu', 'O'),
#  ('thoát', 'O'),
#  ('khỏi', 'O'),
#  ('Barcelona', 'B-LOCATION'),
#  ('Vào', 'O'),
#  ('năm', 'O'),
#  ('2012,', 'B-DATETIME'),
#  ('trước', 'O'),
#  ('khi', 'O'),
#  ('chuyển', 'O'),
#  ('đến', 'O'),
#  ('chơi', 'O'),
#  ('bóng', 'O'),
#  ('tại', 'O'),
#  ('Nou', 'B-LOCATION'),
#  ('Camp,', 'I-LOCATION'),
#  ('tiền', 'O'),
#  ('đạo', 'O'),
#  ('Neymar', 'B-PERSON'),
#  ('đã', 'O'),
#  ('từng', 'O'),
#  ('chia', 'O'),
#  ('sẻ..', 'O'),
#  ('"Tiết', 'O'),
#  ('lộ', 'O'),
#  ('của', 'O'),
#  ('""cô', 'B-PERSON'),
#  ('Bích""', 'I-PERSON'),
#  ('về', 'O'),
#  ('mối', 'O'),
#  ('quan', 'O'),
#  ('hệ', 'O'),
#  ('bầy', 'O'),
#  ('đàn', 'O'),
#  ('của', 'O'),
#  ('những', 'O'),
#  ('người', 'O'),
#  ('đồng', 'O'),
#  ('tính', 'O'),
#  ('ở', 'O'),
#  ('khu', 'O'),
#  ('""chợ', 'O'),
#  ('tình""', 'O'),
#  ('khiến', 'O'),
#  ('tôi', 'O'),
#  ('gai', 'O'),
#  ('người.."', 'O'),
#  ('(VnMedia)', 'O'),
#  ('-', 'O'),
#  ('Đội', 'O'),
#  ('trình', 'O'),
#  ('diễn', 'O'),
#  ('bay', 'O'),
#  ('nổi', 'O'),
#  ('tiếng', 'O'),
#  ('của', 'O'),
#  ('Nga', 'B-LOCATION'),
#  ('Strizhi', 'O'),
#  ('hôm', 'B-DATETIME'),
#  ('6/5', 'I-DATETIME'),
#  ('đã', 'O'),
#  ('trình', 'O'),
#  ('diễn', 'O'),
#  ('một', 'O'),
#  ('màn', 'O'),
#  ('bay', 'O'),
#  ('ngoạn', 'O'),
#  ('mục', 'O'),
#  ('nhân', 'O'),
#  ('dịp', 'O'),
#  ('kỷ', 'O'),
#  ('niệm', 'O'),
#  ('20', 'O'),
#  ('năm', 'O'),
#  ('ngày', 'O'),
#  ('thành', 'O'),
#  ('lập', 'O'),
#  ('đội..', 'O'),
#  ('Bước', 'O'),
#  ('6', 'O'),
#  (':', 'O'),
#  ('Khi', 'O'),
#  ('dầu', 'O'),
#  ('đã', 'O'),
#  ('nóng,', 'O'),
#  ('đưa', 'O'),
#  ('từ', 'O'),
#  ('từ', 'O'),
#  ('muỗng', 'O'),
#  ('bột', 'O'),
#  ('vào', 'O'),
#  ('chảo,', 'O'),
#  ('nghiêng', 'O'),
#  ('muỗng', 'O'),
#  ('để', 'O'),
#  ('đổ', 'O'),
#  ('bánh', 'O'),
#  ('xuống', 'O'),
#  ('chảo', 'O'),
#  ('dầu..', 'O'),
#  ('Sau', 'O'),
#  ('khi', 'O'),
#  ('đền', 'O'),
#  ('bù', 'O'),
#  ('cho', 'O'),
#  ('người', 'O'),
#  ('dân', 'O'),
#  ('xong,', 'O'),
#  ('chủ', 'O'),
#  ('lò', 'O'),
#  ('phải', 'O'),
#  ('chuyển', 'O'),
#  ('sang', 'O'),
#  ('đốt', 'O'),
#  ('gạch', 'O'),
#  ('bằng', 'O'),
#  ('công', 'O'),
#  ('nghệ', 'O'),
#  ('tuy-nen', 'O'),
#  ('hoặc', 'O'),
#  ('chuyển', 'O'),
#  ('sang', 'O'),
#  ('trang', 'O'),
#  ('trại', 'O'),
#  ('nuôi', 'O'),
#  ('cá,', 'O'),
#  ('lúa..', 'O'),
#  ('Chuẩn', 'O'),
#  ('bị', 'O'),
#  ('chương', 'O'),
#  ('trình', 'O'),
#  ('đào', 'O'),
#  ('tạo', 'O'),
#  ('trong', 'O'),
#  ('5', 'O'),
#  ('năm', 'O'),
#  ('tới', 'O'),
#  ('Theo', 'O'),
#  ('báo', 'O'),
#  ('cáo', 'O'),
#  ('chưa', 'O'),
#  ('đầy', 'O'),
#  ('đủ,', 'O'),
#  ('số', 'O'),
#  ('tiền', 'O'),
#  ('mà', 'O'),
#  ('các', 'O'),
#  ('doanh', 'O'),
#  ('nghiệp', 'O'),
#  ('hỗ', 'O'),
#  ('trợ', 'O'),
#  ('cho', 'O'),
#  ('các', 'O'),
#  ('cơ', 'O'),
#  ('sở', 'O'),
#  ('giáo', 'O'),
#  ('dục', 'O'),
#  ('đại', 'O'),
#  ('học,', 'O'),
#  ('cao', 'O'),
#  ('đẳng,', 'O'),
#  ('dạy', 'O'),
#  ('nghề', 'O'),
#  ('trong', 'O'),
#  ('3', 'O'),
#  ('năm', 'O'),
#  ('qua', 'O'),
#  ('lên', 'O'),
#  ('đến', 'O'),
#  ('trên', 'O'),
#  ('12', 'O'),
#  ('triệu', 'O'),
#  ('USD..', 'O'),
#  ('Ông', 'O'),
#  ('Ja', 'B-PERSON'),
#  ('Song-nam', 'I-PERSON'),
#  ('mô', 'O'),
#  ('tả', 'O'),
#  ('cuộc', 'O'),
#  ('họp', 'O'),
#  ('của', 'O'),
#  ('Hội', 'B-ORGANIZATION'),
#  ('đồng', 'I-ORGANIZATION'),
#  ('Bảo', 'I-ORGANIZATION'),
#  ('an', 'I-ORGANIZATION'),
#  ('LHQ', 'I-ORGANIZATION'),
#  ('như', 'O'),
#  ('một', 'O'),
#  ('biện', 'O'),
#  ('pháp', 'O'),
#  ('vô', 'O'),
#  ('vọng', 'O'),
#  ('trong', 'O'),
#  ('sợ', 'O'),
#  ('hãi', 'O'),
#  ('của', 'O'),
#  ('Mỹ', 'B-LOCATION'),
#  ('với', 'O'),
#  ('sức', 'O'),
#  ('mạnh', 'O'),
#  ('của', 'O'),
#  ('Triều', 'B-LOCATION'),
#  ('Tiên', 'I-LOCATION'),
#  ('đạt', 'O'),
#  ('được', 'O'),
#  ('thành', 'O'),
#  ('công', 'O'),
#  ('lịch', 'O'),
#  ('sử,', 'O'),
#  ('hoàn', 'O'),
#  ('tất', 'O'),
#  ('trở', 'O'),
#  ('thành', 'O'),
#  ('một', 'O'),
#  ('quốc', 'O'),
#  ('gia', 'O'),
#  ('hạt', 'O'),
#  ('nhân', 'O'),
#  ('..', 'O'),
#  ('Nhờ', 'O'),
#  ('đó', 'O'),
#  ('gắn', 'O'),
#  ('kết', 'O'),
#  ('hơn', 'O'),
#  ('hẳn', 'O'),
#  ('để', 'O'),
#  ('rồi', 'O'),
#  ('bùng', 'O'),
#  ('nổ', 'O'),
#  ('thực', 'O'),
#  ('sự', 'O'),
#  ('trong', 'O'),
#  ('trận', 'O'),
#  ('đấu', 'O'),
#  ('với', 'O'),
#  ('Deportivo', 'B-ORGANIZATION'),
#  ('ngày', 'B-DATETIME'),
#  ('hôm', 'I-DATETIME'),
#  ('nay..', 'I-DATETIME'),
#  ('Mùa', 'O'),
#  ('khô', 'O'),
#  ('năm', 'B-DATETIME'),
#  ('2010', 'I-DATETIME'),
#  ('đến', 'O'),
#  ('sớm,', 'O'),
#  ('thời', 'O'),
#  ('tiết', 'O'),
#  ('nóng', 'O'),
#  ('bức', 'O'),
#  ('và', 'O'),
#  ('khô', 'O'),
#  ('hạn', 'O'),
#  ('kéo', 'O'),
#  ('dài', 'O'),
#  ('nên', 'O'),
#  ('công', 'O'),
#  ('tác', 'O'),
#  ('PCCC', 'O'),
#  ('được', 'O'),
#  ('quan', 'O'),
#  ('tâm', 'O'),
#  ('chỉ', 'O'),
#  ('đạo', 'O'),
#  ('quyết', 'O'),
#  ('liệt..', 'O'),
#  ('Tại', 'O'),
#  ('sao', 'O'),
#  ('họ', 'O'),
#  ('lại', 'O'),
#  ('đặt', 'O'),
#  ('cái', 'O'),
#  ('tên', 'O'),
#  ('này', 'O'),
#  ('cho', 'O'),
#  ('cảnh', 'O'),
#  ('tượng', 'O'),
#  ('ánh', 'O'),
#  ('sáng', 'O'),
#  ('phát', 'O'),
#  ('quang', 'O'),
#  ('một', 'O'),
#  ('cách', 'O'),
#  ('huyền', 'O'),
#  ('bí', 'O'),
#  ('trên', 'O'),
#  ('bầu', 'O'),
#  ('trời', 'O'),
#  ('?.', 'O'),
#  ('Tất', 'O'),
#  ('nhiên,', 'O'),
#  ('tên', 'O'),
#  ('trùm', 'O'),
#  ('tội', 'O'),
#  ('phạm', 'O'),
#  ('đang', 'O'),
#  ('ẩn', 'O'),
#  ('náu', 'O'),
#  ('trong', 'O'),
#  ('khoang', 'O'),
#  ('bí', 'O'),
#  ('mật', 'O'),
#  ('đó..', 'O'),
#  ('Theo', 'O'),
#  ('đó,', 'O'),
#  ('vào', 'O'),
#  ('những', 'O'),
#  ('năm', 'O'),
#  ('đầu', 'O'),
#  ('của', 'O'),
#  ('thập', 'O'),
#  ('niên', 'O'),
#  ('90,', 'O'),
#  ('nhiều', 'O'),
#  ('hộ', 'O'),
#  ('dân', 'O'),
#  ('ở', 'O'),
#  ('vùng', 'O'),
#  ('đất', 'O'),
#  ('đầy', 'O'),
#  ('nắng', 'O'),
#  ('gió', 'O'),
#  ('Ninh', 'B-LOCATION'),
#  ('Thuận', 'I-LOCATION'),
#  ('bắt', 'O'),
#  ('đầu', 'O'),
#  ('tiếp', 'O'),
#  ('cận', 'O'),
#  ('với', 'O'),
#  ('cây', 'O'),
#  ('nho', 'O'),
#  ('và', 'O'),
#  ('sống', 'O'),
#  ('dựa', 'O'),
#  ('vào', 'O'),
#  ('loại', 'O'),
#  ('cây', 'O'),
#  ('này..', 'O'),
#  ('Bản', 'O'),
#  ('thân', 'O'),
#  ('bác', 'O'),
#  ('sĩ', 'O'),
#  ('cũng', 'O'),
#  ('đã', 'O'),
#  ('nhận', 'O'),
#  ('lỗi', 'O'),
#  ('của', 'O'),
#  ('mình..', 'O'),
#  ('Mesut', 'B-PERSON'),
#  ('Oezil', 'I-PERSON'),
#  ('(Arsenal)', 'B-ORGANIZATION'),
#  (':', 'O'),
#  ('6', 'O'),
#  ('đường', 'O'),
#  ('kiến', 'O'),
#  ('tạo..', 'O'),
#  ('Á', 'O'),
#  ('hậu', 'O'),
#  ('Thụy', 'B-PERSON'),
#  ('Vân', 'I-PERSON'),
#  ('khéo', 'O'),
#  ('khoe', 'O'),
#  ('ngực', 'O'),
#  ('đầy,', 'O'),
#  ('vai', 'O'),
#  ('nuột..', 'O'),
#  ('Công', 'O'),
#  ('bố', 'O'),
#  ('quyết', 'O'),
#  ('định', 'O'),
#  ('thanh', 'O'),
#  ('tra', 'O'),
#  ('tại', 'O'),
#  ('UBND', 'B-ORGANIZATION'),
#  ('tỉnh', 'I-ORGANIZATION'),
#  ('Yên', 'I-ORGANIZATION'),
#  ('Bái..', 'I-ORGANIZATION'),
#  ('"""Ý', 'O'),
#  ('tưởng', 'O'),
#  ('thị', 'O'),
#  ('trường', 'O'),
#  ('đó', 'O'),
#  ('không', 'O'),
#  ('thay', 'O'),
#  ('đổi', 'O'),
#  ('dù', 'O'),
#  ('có', 'O'),
#  ('khủng', 'O'),
#  ('hoảng', 'O'),
#  ('kinh', 'O'),
#  ('tế.."', 'O'),
#  ('Ở', 'O'),
#  ('chiều', 'O'),
#  ('ngược', 'O'),
#  ('lại,', 'O'),
#  ('máy', 'O'),
#  ('sấy', 'O'),
#  ('tóc', 'O'),
#  ('cũng', 'O'),
#  ('tỏ', 'O'),
#  ('ra', 'O'),
#  ('cao', 'O'),
#  ('tay', 'O'),
#  ('khi', 'O'),
#  ('lần', 'O'),
#  ('lượt', 'O'),
#  ('tung', 'O'),
#  ('Javier', 'B-PERSON'),
#  ('Hernandez', 'I-PERSON'),
#  ('và', 'O'),
#  ('Federico', 'B-PERSON'),
#  ('Macheda', 'I-PERSON'),
#  ('vào', 'O'),
#  ('sân..', 'O'),
#  ('Milan', 'B-LOCATION'),
#  ('hiện', 'O'),
#  ('đứng', 'O'),
#  ('thứ', 'O'),
#  ('8', 'O'),
#  ('với', 'O'),
#  ('21', 'O'),
#  ('điểm,', 'O'),
#  ('kém', 'O'),
#  ('đến', 'O'),
#  ('18', 'O'),
#  ('điểm', 'O'),
#  ('so', 'O'),
#  ('với', 'O'),
#  ('vị', 'O'),
#  ('trí', 'O'),
#  ('mà', 'O'),
#  ('Inter', 'B-ORGANIZATION'),
#  ('đang', 'O'),
#  ('nắm', 'O'),
#  ('giữ..', 'O'),
#  ('Ông', 'O'),
#  ('Pong', 'B-PERSON'),
#  ('Visedpaitoon', 'I-PERSON'),
#  ('thuộc', 'O'),
#  ('tập', 'O'),
#  ('đoàn', 'O'),
#  ('Charoen', 'B-ORGANIZATION'),
#  ('Pokphand', 'I-ORGANIZATION'),
#  ('Foods', 'I-ORGANIZATION'),
#  ('Thái', 'I-ORGANIZATION'),
#  ('Lan', 'I-ORGANIZATION'),
#  ('cho', 'O'),
#  ('biết,', 'O'),
#  ('nước', 'O'),
#  ('Mỹ', 'B-LOCATION'),
#  ('sẽ', 'O'),
#  ('phải', 'O'),
#  ('đối', 'O'),
#  ('phó', 'O'),
#  ('với', 'O'),
#  ('vấn', 'O'),
#  ('đề', 'O'),
#  ('thiếu', 'O'),
#  ('tôm', 'O'),
#  ('trong', 'O'),
#  ('khoảng', 'O'),
#  ('nửa', 'O'),
#  ('năm..', 'O'),
#  ('Nó', 'O'),
#  ('liên', 'O'),
#  ('quan', 'O'),
#  ('đến', 'O'),
#  ('tình', 'O'),
#  ('cảm', 'O'),
#  ('dân', 'O'),
#  ('tộc', 'O'),
#  ('và', 'O'),
#  ('quan', 'O'),
#  ('trọng', 'O'),
#  ('hơn', 'O'),
#  ('nó', 'O'),
#  ('giúp', 'O'),
#  ('Trung', 'B-LOCATION'),
#  ('Quốc', 'I-LOCATION'),
#  ('khẳng', 'O'),
#  ('định', 'O'),
#  ('sự', 'O'),
#  ('toàn', 'O'),
#  ('vẹn', 'O'),
#  ('lãnh', 'O'),
#  ('thổ', 'O'),
#  ('..', 'O'),
#  ('BHL', 'O'),
#  ('sẽ', 'O'),
#  ('còn', 'O'),
#  ('đôn', 'O'),
#  ('6', 'O'),
#  ('cầu', 'O'),
#  ('thủ', 'O'),
#  ('tuyến', 'O'),
#  ('U21', 'O'),
#  ('lên', 'O'),
#  ('đội', 'O'),
#  ('1..', 'O'),
#  ...]

# %% [markdown]
# Tính Emission Probability và Transition Probability từ dữ liệu huấn luyện

# %%
# compute Emission Probability (Xác suất để một từ theo 1 nhãn)
def word_given_tag(word, tag, train_bag = train_tagged_words):
    ### 4. BEGIN CODE HERE ###
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)#total number of times the passed tag occurred in train_bag
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    #now calculate the total number of times the passed word occurred as the passed tag.
    count_w_given_tag = len(w_given_tag_list)
    ### 4. END CODE HERE ###
     
    return (count_w_given_tag, count_tag)

# %%
# compute  Transition Probability
def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# Tạo ma trận chuyển trạng thái
# creating t x t transition matrix of tags, t= no of tags
# Matrix(i, j) represents P(jth tag after the ith tag)
 
tags_matrix = np.zeros((len(tags), len(tags)), dtype='float32')
for i, t1 in enumerate(list(tags)):
    for j, t2 in enumerate(list(tags)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]
 
print(tags_matrix)
# Out:
# [[2.65015811e-01 6.84931502e-03 6.63856685e-01 0.00000000e+00
#   4.74183355e-03 0.00000000e+00 1.00105377e-02 0.00000000e+00
#   4.95258160e-02]
#  [0.00000000e+00 2.40460020e-02 2.96393096e-01 6.51332974e-01
#   5.22739161e-03 0.00000000e+00 3.13643483e-03 0.00000000e+00
#   1.98640879e-02]
#  [0.00000000e+00 1.22056017e-02 9.59923029e-01 0.00000000e+00
#   3.96967214e-03 0.00000000e+00 8.99640284e-03 0.00000000e+00
#   1.48976780e-02]
#  [0.00000000e+00 9.19798091e-02 5.70947826e-01 3.01177800e-01
#   1.17779020e-02 0.00000000e+00 1.06561976e-02 0.00000000e+00
#   1.34604601e-02]
#  [0.00000000e+00 5.07614203e-03 2.16582060e-01 0.00000000e+00
#   5.07614203e-03 7.54653156e-01 1.01522841e-02 0.00000000e+00
#   8.46023671e-03]
#  [0.00000000e+00 2.11538468e-02 7.63461530e-01 0.00000000e+00
#   9.61538497e-03 1.42307699e-01 3.84615399e-02 0.00000000e+00
#   2.50000004e-02]
#  [0.00000000e+00 1.27055310e-02 4.43198800e-01 0.00000000e+00
#   5.97907323e-03 0.00000000e+00 2.31689084e-02 5.02989531e-01
#   1.19581465e-02]
#  [0.00000000e+00 2.76301801e-02 2.77895868e-01 0.00000000e+00
#   4.25079698e-03 0.00000000e+00 2.65674815e-02 6.42401695e-01
#   2.12539844e-02]
#  [6.24440491e-01 8.95255129e-04 3.50492388e-01 0.00000000e+00
#   2.23813788e-03 0.00000000e+00 1.79051026e-03 0.00000000e+00
#   2.01432407e-02]]

# %%
# convert the matrix to a df for better readability
#the table is same as the transition table shown in section 3 of article
tags_df = pd.DataFrame(tags_matrix, columns = list(tags), index=list(tags))
display(tags_df)
# Out:
#                 I-PERSON  B-LOCATION         O  I-LOCATION  B-DATETIME  \
# I-PERSON        0.265016    0.006849  0.663857    0.000000    0.004742
# B-LOCATION      0.000000    0.024046  0.296393    0.651333    0.005227
# O               0.000000    0.012206  0.959923    0.000000    0.003970
# I-LOCATION      0.000000    0.091980  0.570948    0.301178    0.011778
# B-DATETIME      0.000000    0.005076  0.216582    0.000000    0.005076
# I-DATETIME      0.000000    0.021154  0.763462    0.000000    0.009615
# B-ORGANIZATION  0.000000    0.012706  0.443199    0.000000    0.005979
# I-ORGANIZATION  0.000000    0.027630  0.277896    0.000000    0.004251
# B-PERSON        0.624440    0.000895  0.350492    0.000000    0.002238
#
#                 I-DATETIME  B-ORGANIZATION  I-ORGANIZATION  B-PERSON
# I-PERSON          0.000000        0.010011        0.000000  0.049526
# B-LOCATION        0.000000        0.003136        0.000000  0.019864
# O                 0.000000        0.008996        0.000000  0.014898
# I-LOCATION        0.000000        0.010656        0.000000  0.013460
# B-DATETIME        0.754653        0.010152        0.000000  0.008460
# I-DATETIME        0.142308        0.038462        0.000000  0.025000
# B-ORGANIZATION    0.000000        0.023169        0.502990  0.011958
# I-ORGANIZATION    0.000000        0.026567        0.642402  0.021254
# B-PERSON          0.000000        0.001791        0.000000  0.020143

# %% [markdown]
# Xây dựng thuật toán Viterbi

# %%
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))

    #lặp từng từ
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        #Lặp từng nhãn tính xác suất chuyển đổi từ nhãn trước tới các nhãn hiện tại.
        for tag in T:
            ### 5. BEGIN CODE HERE ###

            if key == 0:
                transition_p = tags_df.loc['O', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                 
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            ### 5. END CODE HERE ###


        ### 6. BEGIN CODE HERE ###
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)]
        ### 6. END CODE HERE ###

        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# Test thuật toán Viterbi

# %%
# Let's test our Viterbi algorithm on a few sample sentences of test dataset
random.seed(10)      #define a random seed to get same sentences when run multiple times
 
# choose random 10 numbers
rndom = [random.randint(1,len(test_set)-1) for x in range(10)]
 
# list of 10 sents on which we test the model
test_run = [test_set[i] for i in rndom]
 
# list of tagged words
test_run_base = [tup for sent in test_run for tup in sent]
 
# list of untagged words
test_tagged_words = [tup[0] for sent in test_run for tup in sent]

# %%
#Here We will only test 10 sentences to check the accuracy
#as testing the whole training set takes huge amount of time
start = time.time()
tagged_seq = Viterbi(test_tagged_words)
end = time.time()
difference = end-start
 
print("Time taken in seconds: ", difference)
 
# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 
 
accuracy = len(check)/len(tagged_seq)
print('Viterbi Algorithm Accuracy: ',accuracy*100)
# Out:
# Time taken in seconds:  65.2182936668396
# Viterbi Algorithm Accuracy:  91.30434782608695

# %%
#Code to test all the test sentences
#(takes alot of time to run)
# tagging the test sentences()

test_tagged_words = [tup for sent in test_set for tup in sent]
test_untagged_words = [tup[0] for sent in test_set for tup in sent]
test_untagged_words

 
start = time.time()
tagged_seq = Viterbi(test_untagged_words)
end = time.time()
difference = end-start
 
print("Time taken in seconds: ", difference)
 
# accuracy
check = [i for i, j in zip(tagged_seq, test_tagged_words) if i == j] 
 
accuracy = len(check)/len(tagged_seq)
print('Viterbi Algorithm Accuracy: ',accuracy*100)
# Out:
# Time taken in seconds:  640.3209068775177
# Viterbi Algorithm Accuracy:  91.19958093242535

# %% [markdown]
# Tăng độ chính xác bằng cách kết hợp thêm rule

# %%
#To improve the performance,we specify a rule base tagger for unknown words 
# specify patterns for tagging
patterns = [
    (r'^(?:(?:31(\/|-|\.)(?:0?[13578]|1[02]))\1|(?:(?:29|30)(\/|-|\.)(?:0?[13-9]|1[0-2])\2))(?:(?:1[6-9]|[2-9]\d)?\d{2})$|^(?:29(\/|-|\.)0?2\3(?:(?:(?:1[6-9]|[2-9]\d)?(?:0[48]|[2468][048]|[13579][26])|(?:(?:16|[2468][048]|[3579][26])00))))$|^(?:0?[1-9]|1\d|2[0-8])(\/|-|\.)(?:(?:0?[1-9])|(?:1[0-2]))\4(?:(?:1[6-9]|[2-9]\d)?\d{2})$', 'B-DATETIME'),              # gerund
]
# rule based tagger
rule_based_tagger = nltk.RegexpTagger(patterns)

# %%
rule_based_tagger.tag(['30/04/1975','là','ngày'])
# Out:
# [('30/04/1975', 'B-DATETIME'), ('là', None), ('ngày', None)]

# %%
#modified Viterbi to include rule based tagger in it
def Viterbi_rule_based(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            ### 6. BEGIN CODE HERE ###
            if key == 0:
                transition_p = tags_df.loc['O', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                 
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            ### 6. END CODE HERE ###

        ### 7. BEGIN CODE HERE ###
        pmax = max(p)
        state_max = rule_based_tagger.tag([word])[0][1] 
        ### 7. END CODE HERE ###
        
        ### 8. BEGIN CODE HERE ###
        if(pmax==0 and rule_based_tagger.tag([word])[0][1] != None ):
            state_max = rule_based_tagger.tag([word])[0][1] # assign based on rule based tagger
        else:
            state_max = T[p.index(pmax)]                
        ### 8. END CODE HERE ###
        state.append(state_max)
    return list(zip(words, state))

# %%
test_tagged_words

# %%
#Kết quả Test cả bộ khá lâu
#test accuracy on subset of test data 
start = time.time()
tagged_seq = Viterbi_rule_based(test_untagged_words)
end = time.time()
difference = end-start
 
print("Time taken in seconds: ", difference)
 
# accuracy
check = [i for i, j in zip(tagged_seq, test_tagged_words) if i == j] 
 
accuracy = len(check)/len(tagged_seq)
print('Viterbi Algorithm Accuracy: ',accuracy*100)
# Out:
# Time taken in seconds:  621.1240074634552
# Viterbi Algorithm Accuracy:  91.19958093242535

# %%
#Check how a sentence is tagged by the two POS taggers
#and compare them
test_sent="ngày 20/12/2022 , cú đúp của Sheva đã mang lại chiến thắng cho Ukraine - một chiến thắng không hề' dễ' dàng.."
pred_tags_rule=Viterbi_rule_based(test_sent.split())
pred_tags_withoutRules= Viterbi(test_sent.split())
print(pred_tags_rule)
print(pred_tags_withoutRules)
#Will and Marry are tagged as NUM as they are unknown words for Viterbi Algorithm
# Out:
# [('ngày', 'O'), ('20/12/2022', 'B-DATETIME'), (',', 'O'), ('cú', 'O'), ('đúp', 'O'), ('của', 'O'), ('Sheva', 'B-PERSON'), ('đã', 'O'), ('mang', 'O'), ('lại', 'O'), ('chiến', 'O'), ('thắng', 'O'), ('cho', 'O'), ('Ukraine', 'B-LOCATION'), ('-', 'I-LOCATION'), ('một', 'O'), ('chiến', 'O'), ('thắng', 'O'), ('không', 'O'), ("hề'", 'O'), ("dễ'", 'I-PERSON'), ('dàng..', 'O')]
# [('ngày', 'O'), ('20/12/2022', 'I-PERSON'), (',', 'O'), ('cú', 'O'), ('đúp', 'O'), ('của', 'O'), ('Sheva', 'B-PERSON'), ('đã', 'O'), ('mang', 'O'), ('lại', 'O'), ('chiến', 'O'), ('thắng', 'O'), ('cho', 'O'), ('Ukraine', 'B-LOCATION'), ('-', 'I-LOCATION'), ('một', 'O'), ('chiến', 'O'), ('thắng', 'O'), ('không', 'O'), ("hề'", 'O'), ("dễ'", 'I-PERSON'), ('dàng..', 'O')]
